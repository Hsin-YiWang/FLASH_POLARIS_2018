# %% [markdown]
# ## Plot out the data from txt file
#
# This log is part of the data_analysis for 1st POLARIS XFEL beamtime at Desy, FLASH (Oct.2018)
#
# (1) We have some data saved in txt which is generated from our analyser computer.
#
# (2) The run number can be found from our google sharging folder.
#
#     https://docs.google.com/spreadsheets/d/1IuuIMmMBfYtifjh5DjGQb39-haKQuAAgKKPYnzIyHx4/edit?usp=sharing
#
# (3) Remember to delete the unnecessary data row in the txt file.
#
# -----------
#  Created by  Hsin-Yi Wang (wang.hy@fysik.su.se), Date: 01-Oct-2018
# - Note: This script shuld be operated under Python 3 environment

# %%
import numpy as np
from matplotlib import pyplot as plt

runs = [37,38]
file_names = ["O1s", "C1s"]
i = 0
while i < len(runs) :
    data=np.loadtxt("/Users/hsin-yiwang/Desktop/Insitucell_for_XPS/FlashBeamtime/DATA/nonHDF5/0%03d.txt"%runs[i])
    X=(data[:,0])
    Y=(data[:,1]) 
    plt.plot(X, Y, label = "data = %s" %file_names[i])
    plt.legend(frameon=False,loc='upper right', prop={'size': 12})
    plt.xlabel('Kinetic energy (eV)',size=12)
    plt.ylabel('Intensity (a. u.)',size=12)
    plt.grid()
    #i = i+1 
    plt.show() # push back if you want to individually plot the data
    i = i+1
